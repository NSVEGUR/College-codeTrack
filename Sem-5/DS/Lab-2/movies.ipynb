# %%
import pandas as pd

# %%
movies_file_path = 'movies.csv'
movies_titles_file_path = 'movieTitles.csv'
movies = pd.read_csv(movies_file_path)
titles = pd.read_csv(movies_titles_file_path)
dataset = pd.merge(movies, titles, left_on='item_id', right_on='item_id')
dataset.describe()
# Out:
#              user_id        item_id         rating     timestamp
# count  100003.000000  100003.000000  100003.000000  1.000030e+05
# mean      462.470876     425.520914       3.529864  8.835288e+08
# std       266.622454     330.797791       1.125704  5.343791e+06
# min         0.000000       1.000000       1.000000  8.747247e+08
# 25%       254.000000     175.000000       3.000000  8.794487e+08
# 50%       447.000000     322.000000       4.000000  8.828269e+08
# 75%       682.000000     631.000000       4.000000  8.882600e+08
# max       943.000000    1682.000000       5.000000  8.932866e+08

# %%
dataset.head()
# Out:
#    user_id  item_id  rating  timestamp             title
# 0        0       50       5  881250949  Star Wars (1977)
# 1      290       50       5  880473582  Star Wars (1977)
# 2       79       50       4  891271545  Star Wars (1977)
# 3        2       50       5  888552084  Star Wars (1977)
# 4        8       50       5  879362124  Star Wars (1977)

# %% [markdown]
# ### Count Users

# %%
counts = dataset.max()
print(counts.user_id)
# Out:
# 943

# %% [markdown]
# ### Count Movies

# %%
print(counts.item_id)
# Out:
# 1682

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100003 entries, 0 to 100002
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   user_id    100003 non-null  int64
#  1   item_id    100003 non-null  int64
#  2   rating     100003 non-null  int64
#  3   timestamp  100003 non-null  int64
#  4   title      100003 non-null  object
# dtypes: int64(4), object(1)
# memory usage: 4.6+ MB

# %%
pivot = dataset.pivot_table(index="user_id", columns="title", values="rating")
pivot.head()
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 0                        NaN         NaN                          NaN
# 1                        5.0         NaN                          NaN
# 2                        NaN         NaN                          NaN
# 3                        NaN         2.0                          NaN
# 4                        NaN         NaN                          NaN
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# ...

# %%
def recommend_movie(movie_title, n):
	movie_rating = pivot[movie_title]
	similar_to_movie = pivot.corrwith(movie_rating)
	corr = pd.DataFrame(similar_to_movie, columns=["correlation"])
	corr.dropna(inplace = True)
	return corr.sort_values(by='correlation', ascending=False).head(n)
recommend_movie('American Dream (1990)', 5)
# Out:
# /Users/nagasaivegur/Developer/anaconda3/lib/python3.9/site-packages/numpy/lib/function_base.py:2683: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /Users/nagasaivegur/Developer/anaconda3/lib/python3.9/site-packages/numpy/lib/function_base.py:2542: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
#                                      correlation
# title
# 12 Angry Men (1957)                          1.0
# Once Were Warriors (1994)                    1.0
# Muriel's Wedding (1994)                      1.0
# Mute Witness (1994)                          1.0
# My Crazy Life (Mi vida loca) (1993)          1.0
